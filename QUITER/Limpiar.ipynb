# %%
import pandas as pd

# %%
df=pd.read_excel('U22902-2024-09-06.xls')
df
# Out:
#               Chasis Nombre               Version  Modelo  \
# 0  YV1XZ16A1M2566313   XC40    XC40 R-DESIGN 2021  2021.0
# 1  YV1XZEDA9N2642257   XC40  XC40 BEV ELECTRICO T  2022.0
# 2  YV1XZBBA4P2951638   XC40  XC40 RECHARGE ULTIMA  2023.0
# 3  YV1UZH2A8R1912646   XC60   XC60 RECHARGE BLACK  2024.0
# 4  YV1UZH2A6P1282994   XC60  XC60 RECHARGE ULTIMA  2023.0
# 5  YV1LFBR05M1726179   XC90  XC90 INSCRIPTION HYB  2021.0
# 6                NaN    NaN                   NaN     NaN
# 7          *** TOTAL    NaN                   NaN     NaN
#
#                  Color                   Interior Transmision  Cilindros  \
# 0        CRYSTAL WHITE  CHARCOAL/ARIENNE/CHARCOAL           A        4.0
# 1       GLACIER SILVER                      NEGRO           A        0.0
# 2  CRYSTAL WHITE PEARL  CHARCOAL/ARIANNE/CHARCOAL           A        3.0
# 3           ONYX BLACK     CHARCOAL/LEAC/CHARCOAL           A        4.0
# 4  CRYSTAL WHITE PEARL  CHARCOAL/LEABR3/CHARC/SPO           A        4.0
# ...

# %%
df.drop(df.index[[6,7]])
df.shape
# Out:
# (8, 11)
